# %% [markdown]
# # Stock predict system

# %%
# !pip install "numpy<2.3"
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import re
import json
import pandas as pd
import numpy as np
import pandas_ta as ta
from pathlib import Path
from tqdm import tqdm

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import pipeline
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef

warnings.filterwarnings('ignore')

# %%
class BertPreprocessor:
    def __init__(self, root_dir):
        self.root = Path(root_dir)
        self.price_dir = self.root / 'price' / 'raw'
        self.tweet_dir = self.root / 'tweet' / 'preprocessed'
        self.device = 0 if torch.cuda.is_available() else -1
        model_kwargs = {"dtype": torch.float16} if self.device == 0 else {}
        self.sentiment_pipe = pipeline(
            "sentiment-analysis",
            model="nlptown/bert-base-multilingual-uncased-sentiment",
            device=self.device,
            model_kwargs=model_kwargs
        )

    def _clean_and_concat(self, text_list, ticker):
        cleaned_tweets = []
        for text in text_list:
            text = str(text).lower()
            text = re.sub(r'http\S+|www\S+|https\S+', '', text)
            text = re.sub(rf'\b{ticker.lower()}\b', '', text)
            text = re.sub(r'\b(rt|inc|ie)\b', '', text)
            text = re.sub(r'[^a-z\s]', '', text)
            clean_text = text.strip()
            if clean_text:
                cleaned_tweets.append(clean_text)
        return " ".join(cleaned_tweets)

    def process_all_data(self):
        target_tickers = [f.stem for f in self.price_dir.glob('*.csv')]
        all_data = []
        for ticker in tqdm(target_tickers):
            price_path = self.price_dir / f"{ticker}.csv"
            try:
                df_price = pd.read_csv(price_path)
                df_price['Date'] = pd.to_datetime(df_price['Date'])
                df_price.set_index('Date', inplace=True)
                df_price.sort_index(inplace=True)

                if 'Adj Close' in df_price.columns:
                    if 'Close' in df_price.columns:
                        df_price = df_price.drop(columns=['Close'])
                    df_price.rename(columns={'Adj Close': 'Close'}, inplace=True)

                for col in ['Open', 'High', 'Low', 'Close', 'Volume']:
                    if col in df_price.columns:
                        df_price[col] = pd.to_numeric(df_price[col], errors='coerce')

                df_price.ta.ema(length=12, append=True)
                df_price.ta.ema(length=26, append=True)
                df_price.ta.ema(length=50, append=True)

                df_price.ta.macd(fast=12, slow=26, signal=9, append=True)
                df_price.ta.rsi(length=14, append=True)
                df_price.ta.stochrsi(length=14, append=True)
                if {'High', 'Low', 'Close'}.issubset(df_price.columns):
                    df_price.ta.atr(length=14, append=True)

                df_price.ta.bbands(length=20, std=2, append=True)

                if {'Close', 'Volume'}.issubset(df_price.columns):
                    df_price.ta.obv(append=True)

                df_price['Target'] = (df_price['Close'].shift(-1) > df_price['Close']).astype(int)
            except Exception:
                continue

            ticker_tweet_dir = self.tweet_dir / ticker
            tweet_records = []
            if ticker_tweet_dir.exists():
                for date_file in ticker_tweet_dir.iterdir():
                    if not date_file.is_file(): continue
                    daily_texts = []
                    try:
                        with open(date_file, 'r', encoding='utf-8') as f:
                            for line in f:
                                try:
                                    daily_texts.append(json.loads(line).get('text', ''))
                                except: pass
                    except: pass
                    if daily_texts:
                        combined_text = self._clean_and_concat(daily_texts, ticker)
                        if combined_text:
                            try:
                                res = self.sentiment_pipe(combined_text, truncation=True, max_length=512)[0]
                                score = int(res['label'].split()[0])
                                tweet_records.append({
                                    'Date': pd.to_datetime(date_file.name),
                                    'Sentiment_Score': score,
                                    'Tweet_Volume': len(daily_texts)
                                })
                            except:
                                pass

            if tweet_records:
                df_tweet = pd.DataFrame(tweet_records).set_index('Date')
                df_merged = df_price.join(df_tweet, how='left')
            else:
                df_merged = df_price.copy()
                df_merged['Sentiment_Score'] = 3
                df_merged['Tweet_Volume'] = 0

            df_merged['Ticker'] = str(ticker)
            all_data.append(df_merged)

        if not all_data:
            raise ValueError("No data processed successfully.")

        master_df = pd.concat(all_data)
        master_df['Sentiment_Score'] = master_df['Sentiment_Score'].fillna(3)
        master_df['Tweet_Volume'] = master_df['Tweet_Volume'].fillna(0)

        master_df = master_df.reset_index()
        cols_to_ffill = [c for c in master_df.columns if c not in ['Ticker', 'Date']]
        master_df[cols_to_ffill] = master_df.groupby('Ticker')[cols_to_ffill].ffill()
        master_df = master_df.set_index('Date').dropna()

        return master_df

# %%
class StockDataset(Dataset):
    def __init__(self, features, targets):
        self.features = torch.FloatTensor(features)
        self.targets = torch.FloatTensor(targets)
    def __len__(self): return len(self.features)
    def __getitem__(self, idx): return self.features[idx], self.targets[idx]

def create_sequences(df, feature_cols, seq_length):
    xs, ys = [], []
    for ticker, group in df.groupby('Ticker'):
        group = group.sort_index()
        feature_data = group[feature_cols].values
        target_data = group['Target'].values
        for i in range(len(group) - seq_length):
            xs.append(feature_data[i : i + seq_length])
            ys.append(target_data[i + seq_length - 1])
    return np.array(xs), np.array(ys)

# %% [markdown]
# ~~~~+ Check if the test data has been read successfully

# %%
class UniversalStockPredictor(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, rnn_type='LSTM', bidirectional=False):
        super().__init__()
        self.rnn_type = rnn_type
        self.bidirectional = bidirectional

        if rnn_type == 'LSTM':
            self.rnn = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, bidirectional=bidirectional)
        elif rnn_type == 'GRU':
            self.rnn = nn.GRU(input_dim, hidden_dim, num_layers, batch_first=True, bidirectional=bidirectional)

        self.fc = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        rnn_out, _ = self.rnn(x)
        return self.sigmoid(self.fc(rnn_out[:, -1, :])).squeeze()

# %%
def train_and_evaluate(train_df, test_df, feature_cols, seq_length, batch_size, epochs, lr, device, rnn_type, is_bi, model_name):
    scaler = StandardScaler()
    train_feat = scaler.fit_transform(train_df[feature_cols])
    test_feat = scaler.transform(test_df[feature_cols])

    train_df_exp, test_df_exp = train_df.copy(), test_df.copy()
    train_df_exp[feature_cols] = train_feat
    test_df_exp[feature_cols] = test_feat

    X_train, y_train = create_sequences(train_df_exp, feature_cols, seq_length)
    X_test, y_test = create_sequences(test_df_exp, feature_cols, seq_length)

    train_loader = DataLoader(StockDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(StockDataset(X_test, y_test), batch_size=batch_size, shuffle=False)

    model = UniversalStockPredictor(len(feature_cols), 64, 2, rnn_type=rnn_type, bidirectional=is_bi).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCELoss()

    for epoch in range(epochs):
        model.train()
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            loss = criterion(model(X_batch.to(device)), y_batch.to(device))
            loss.backward()
            optimizer.step()

    model.eval()
    all_preds, all_targets = [], []
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            outputs = model(X_batch.to(device))
            if outputs.dim() == 0:
                outputs = outputs.unsqueeze(0)
            all_preds.extend((outputs > 0.5).float().cpu().numpy())
            all_targets.extend(y_batch.numpy())

    acc = accuracy_score(all_targets, all_preds)
    prec = precision_score(all_targets, all_preds, zero_division=0)
    rec = recall_score(all_targets, all_preds, zero_division=0)
    f1 = f1_score(all_targets, all_preds, zero_division=0)
    mcc = matthews_corrcoef(all_targets, all_preds)

    print(f"{model_name:<8} | {prec:<9.4f} | {rec:<7.4f} | {f1:<7.4f} | {mcc:<7.4f} | {acc:<8.4f}")

# %%
if __name__ == "__main__":
    DATA_PATH = './stocknet-dataset'
    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"System Device: {DEVICE}")

    preprocessor = BertPreprocessor(DATA_PATH)
    df = preprocessor.process_all_data()

    dates = df.index.unique().sort_values()
    train_split_idx = int(len(dates) * 0.8)
    train_df = df[df.index.isin(dates[:train_split_idx])]
    test_df = df[df.index.isin(dates[train_split_idx:])]

    base_ta_features = [
        'Open', 'High', 'Low', 'Close', 'Volume',
        'EMA_12', 'EMA_26', 'EMA_50',
        'MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9',
        'RSI_14',
        'STOCHRSIk_14_14_3_3', 'STOCHRSId_14_14_3_3',
        'ATRr_14', 'ATR_14',
        'BBL_20_2.0_2.0', 'BBM_20_2.0_2.0', 'BBU_20_2.0_2.0',
        'OBV'
    ]

    tech_features = [c for c in base_ta_features if c in df.columns]
    sentiment_features = ['Sentiment_Score', 'Tweet_Volume']
    all_features = tech_features + sentiment_features

    model_configs = [
        ('LSTM', False, 'LSTM'),
        ('LSTM', True, 'BiLSTM'),
        ('GRU', False, 'GRU'),
        ('GRU', True, 'BiGRU')
    ]

    print("\nEvaluation Results: Classification models (Technical Indicators Only)")
    print(f"{'Setting':<8} | {'Precision':<9} | {'Recall':<7} | {'F1':<7} | {'MCC':<7} | {'Accuracy':<8}")
    print("-" * 65)
    for rnn_type, is_bi, name in model_configs:
        train_and_evaluate(train_df, test_df, tech_features, seq_length=5, batch_size=32, epochs=15, lr=0.001, device=DEVICE, rnn_type=rnn_type, is_bi=is_bi, model_name=name)

    print("\nEvaluation Results: Classification models (Technical + BERT Sentiment Features)")
    print(f"{'Setting':<8} | {'Precision':<9} | {'Recall':<7} | {'F1':<7} | {'MCC':<7} | {'Accuracy':<8}")
    print("-" * 65)
    for rnn_type, is_bi, name in model_configs:
        train_and_evaluate(train_df, test_df, all_features, seq_length=5, batch_size=32, epochs=15, lr=0.001, device=DEVICE, rnn_type=rnn_type, is_bi=is_bi, model_name=name)
# Out:
# System Device: cuda
# ...
# 100%|██████████| 88/88 [03:56<00:00,  2.69s/it]
# Evaluation Results: Classification models (Technical Indicators Only)
# Setting  | Precision | Recall  | F1      | MCC     | Accuracy
# -----------------------------------------------------------------
# LSTM     | 0.5266    | 0.7445  | 0.6169  | 0.0105  | 0.5159
# BiLSTM   | 0.5292    | 0.7462  | 0.6192  | 0.0192  | 0.5196
# GRU      | 0.5284    | 0.6218  | 0.5713  | 0.0124  | 0.5115
# BiGRU    | 0.5321    | 0.6395  | 0.5809  | 0.0225  | 0.5169
#
# Evaluation Results: Classification models (Technical + BERT Sentiment Features)
# Setting  | Precision | Recall  | F1      | MCC     | Accuracy
# -----------------------------------------------------------------
# LSTM     | 0.5281    | 0.6797  | 0.5944  | 0.0133  | 0.5144
# BiLSTM   | 0.5271    | 0.8116  | 0.6391  | 0.0147  | 0.5202
# GRU      | 0.5340    | 0.5136  | 0.5236  | 0.0213  | 0.5108
# BiGRU    | 0.5262    | 0.6422  | 0.5784  | 0.0072  | 0.5100

# %%
# %matplotlib inline

score_counts = df['Sentiment_Score'].value_counts().sort_index()

plt.figure(figsize=(9, 6))
sns.set_style("whitegrid")

bars = plt.bar(
    score_counts.index,
    score_counts.values,
    color='#4C72B0',
    edgecolor='black',
    width=0.6
)

plt.title('Distribution of BERT Sentiment Scores', fontsize=16, fontweight='bold', pad=15)
plt.xlabel('Sentiment Score (1 = Extremely Negative, 5 = Extremely Positive)', fontsize=13)
plt.ylabel('Frequency (Number of Days)', fontsize=13)

plt.xticks([1, 2, 3, 4, 5], fontsize=11)
plt.yticks(fontsize=11)

for bar in bars:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        yval + (yval * 0.015),
        int(yval),
        ha='center',
        va='bottom',
        fontsize=11,
        fontweight='bold'
    )

plt.tight_layout()
plt.show()
